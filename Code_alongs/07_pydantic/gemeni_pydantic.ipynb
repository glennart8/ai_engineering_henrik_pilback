# %% [markdown]
# ## Lecture - Pydantic to structure output from LLMs

# %% [markdown]
# ## How you can use a LLM to get data from a JSON-file into a pandas dataframe

# %%
from dotenv import load_dotenv
from google import genai
import os

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make smart decisions or predictions.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""You are a helpful assistant. I need you to create a JSON object representing a library. 
    The library's name should be 'Coolu Libraru' and have the fields name and books that contains a list of book. 
    Each book should have a 'title', 'author', and 'year' field. Make sure the output is a single, valid JSON object. Give me 10 books. 
    Remove ```json and ``` """,
)

response.text
# Out:
# '{\n  "name": "Coolu Libraru",\n  "books": [\n    {\n      "title": "The Hitchhiker\'s Guide to the Galaxy",\n      "author": "Douglas Adams",\n      "year": 1979\n    },\n    {\n      "title": "Pride and Prejudice",\n      "author": "Jane Austen",\n      "year": 1813\n    },\n    {\n      "title": "1984",\n      "author": "George Orwell",\n      "year": 1949\n    },\n    {\n      "title": "To Kill a Mockingbird",\n      "author": "Harper Lee",\n      "year": 1960\n    },\n    {\n      "title": "The Great Gatsby",\n      "author": "F. Scott Fitzgerald",\n      "year": 1925\n    },\n    {\n      "title": "Dune",\n      "author": "Frank Herbert",\n      "year": 1965\n    },\n    {\n      "title": "Moby Dick",\n      "author": "Herman Melville",\n      "year": 1851\n    },\n    {\n      "title": "Brave New World",\n      "author": "Aldous Huxley",\n      "year": 1932\n    },\n    {\n      "title": "The Lord of the Rings",\n      "author": "J.R.R. Tolkien",\n      "year": 1954\n    },\n    {\n      "title": "One Hundred Years of Solitude",\n      "author": "Gabriel García Márquez",\n      "year": 1967\n    }\n  ]\n}'

# %%
print(response.text)
# Out:
# {
#   "name": "Coolu Libraru",
#   "books": [
#     {
#       "title": "The Hitchhiker's Guide to the Galaxy",
#       "author": "Douglas Adams",
#       "year": 1979
#     },
#     {
#       "title": "Pride and Prejudice",
#       "author": "Jane Austen",
#       "year": 1813
#     },
#     {
#       "title": "1984",
#       "author": "George Orwell",
#       "year": 1949
#     },
#     {
#       "title": "To Kill a Mockingbird",
#       "author": "Harper Lee",
#       "year": 1960
#     },
#     {
#       "title": "The Great Gatsby",
#       "author": "F. Scott Fitzgerald",
#       "year": 1925
#     },
#     {
#       "title": "Dune",
#       "author": "Frank Herbert",
#       "year": 1965
#     },
#     {
#       "title": "Moby Dick",
#       "author": "Herman Melville",
#       "year": 1851
#     },
#     {
#       "title": "Brave New World",
#       "author": "Aldous Huxley",
#       "year": 1932
#     },
#     {
#       "title": "The Lord of the Rings",
#       "author": "J.R.R. Tolkien",
#       "year": 1954
#     },
#     {
#       "title": "One Hundred Years of Solitude",
#       "author": "Gabriel García Márquez",
#       "year": 1967
#     }
#   ]
# }

# %%
from pydantic import BaseModel, Field
from typing import List
from datetime import datetime

class Book(BaseModel):
    title: str
    author: str
    year: int = Field(gt = 1000, lt = datetime.now().year)
    
class Library(BaseModel):
    name: str
    books: List[Book]
        
library = Library.model_validate_json(response.text)
library
# Out:
# Library(name='Coolu Libraru', books=[Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979), Book(title='Pride and Prejudice', author='Jane Austen', year=1813), Book(title='1984', author='George Orwell', year=1949), Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960), Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925), Book(title='Dune', author='Frank Herbert', year=1965), Book(title='Moby Dick', author='Herman Melville', year=1851), Book(title='Brave New World', author='Aldous Huxley', year=1932), Book(title='The Lord of the Rings', author='J.R.R. Tolkien', year=1954), Book(title='One Hundred Years of Solitude', author='Gabriel García Márquez', year=1967)])

# %%
library.__dict__
# Out:
# {'name': 'Coolu Libraru',
#  'books': [Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979),
#   Book(title='Pride and Prejudice', author='Jane Austen', year=1813),
#   Book(title='1984', author='George Orwell', year=1949),
#   Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960),
#   Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925),
#   Book(title='Dune', author='Frank Herbert', year=1965),
#   Book(title='Moby Dick', author='Herman Melville', year=1851),
#   Book(title='Brave New World', author='Aldous Huxley', year=1932),
#   Book(title='The Lord of the Rings', author='J.R.R. Tolkien', year=1954),
#   Book(title='One Hundred Years of Solitude', author='Gabriel García Márquez', year=1967)]}

# %%
type(library)
# Out:
# __main__.Library

# %%
isinstance(library, BaseModel)
# Out:
# True

# %%
library.name
# Out:
# 'Coolu Libraru'

# %%
library.books
# Out:
# [Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979),
#  Book(title='Pride and Prejudice', author='Jane Austen', year=1813),
#  Book(title='1984', author='George Orwell', year=1949),
#  Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960),
#  Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925),
#  Book(title='Dune', author='Frank Herbert', year=1965),
#  Book(title='Moby Dick', author='Herman Melville', year=1851),
#  Book(title='Brave New World', author='Aldous Huxley', year=1932),
#  Book(title='The Lord of the Rings', author='J.R.R. Tolkien', year=1954),
#  Book(title='One Hundred Years of Solitude', author='Gabriel García Márquez', year=1967)]

# %% [markdown]
# # Extract titles into a lista
# - måste jag extrahera det til en separat lista föra tt få ut endast titlar?

# %%
titles = [book.title for book in library.books]
titles
# Out:
# ["The Hitchhiker's Guide to the Galaxy",
#  'Pride and Prejudice',
#  '1984',
#  'To Kill a Mockingbird',
#  'The Great Gatsby',
#  'Dune',
#  'Moby Dick',
#  'Brave New World',
#  'The Lord of the Rings',
#  'One Hundred Years of Solitude']

# %%
newer_books = [(book.title, book.year) for book in library.books if book.year > 1960]
newer_books
# Out:
# [("The Hitchhiker's Guide to the Galaxy", 1979),
#  ('Dune', 1965),
#  ('One Hundred Years of Solitude', 1967)]

# %% [markdown]
# # to get back json data use model_dump()

# %%
library.model_dump()
# Out:
# {'name': 'Coolu Libraru',
#  'books': [{'title': "The Hitchhiker's Guide to the Galaxy",
#    'author': 'Douglas Adams',
#    'year': 1979},
#   {'title': 'Pride and Prejudice', 'author': 'Jane Austen', 'year': 1813},
#   {'title': '1984', 'author': 'George Orwell', 'year': 1949},
#   {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'year': 1960},
#   {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'year': 1925},
#   {'title': 'Dune', 'author': 'Frank Herbert', 'year': 1965},
#   {'title': 'Moby Dick', 'author': 'Herman Melville', 'year': 1851},
#   {'title': 'Brave New World', 'author': 'Aldous Huxley', 'year': 1932},
#   {'title': 'The Lord of the Rings', 'author': 'J.R.R. Tolkien', 'year': 1954},
#   {'title': 'One Hundred Years of Solitude',
#    'author': 'Gabriel García Márquez',
#    'year': 1967}]}

# %%
with open("library.json", "w") as json_file:
    json_file.write(library.model_dump_json())

# %% [markdown]
# # create pandas dataframe

# %%
import pandas as pd

titles = [book.title for book in library.books]
years = [book.year for book in library.books]
authors = [book.author for book in library.books]

pd.DataFrame({"title": titles, "year": years, "author": authors})
# Out:
#                                   title  year                  author
# 0  The Hitchhiker's Guide to the Galaxy  1979           Douglas Adams
# 1                   Pride and Prejudice  1813             Jane Austen
# 2                                  1984  1949           George Orwell
# 3                 To Kill a Mockingbird  1960              Harper Lee
# 4                      The Great Gatsby  1925     F. Scott Fitzgerald
# 5                                  Dune  1965           Frank Herbert
# 6                             Moby Dick  1851         Herman Melville
# 7                       Brave New World  1932           Aldous Huxley
# 8                 The Lord of the Rings  1954          J.R.R. Tolkien
# 9         One Hundred Years of Solitude  1967  Gabriel García Márquez
