# %% [markdown]
# ## MOBBPROGRAMMERING
#
# En person vill köpa en bostad.
#
# Personen har:
# - inkomst
#
#
# Köpet kräver:
# - pris för bostad
# - avgifter
# - ränta
# - insats
#
#
# validera input för att undvika felaktiga värden
