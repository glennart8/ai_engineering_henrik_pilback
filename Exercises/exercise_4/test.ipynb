# %%
import requests
from pprint import pprint

response = requests.get("http://127.0.0.1:8000/glossary/")

pprint(response.json()[:3])
# Out:
# [{'id': 1,
#   'meaning': 'Request parameters embedded in the URL path to identify a '
#              'resource (variable part of the endpoint path). Example: '
#              '/users/{user_id}.',
#   'word': 'path parameter'},
#  {'id': 2,
#   'meaning': 'A URL path in the API that accepts HTTP requests (e.g., /items, '
#              '/users/{id}).',
#   'word': 'endpoint (route)'},
#  {'id': 3,
#   'meaning': 'Additional keyâ€“value pairs after ? in the URL, used for '
#              'filtering or searching.',
#   'word': 'query parameter'}]

# %%
response = requests.post("http://127.0.0.1:8000/glossary/add/", json={
  "id": 17,
  "word": "hejbabbeddadaddariba",
  "meaning": "kul ord"
})

print(response.json()[0].get("meaning"))
# Out:
# kul ord
