# %% [markdown]
# ### Validate data from API using Pydantic

# %%
import requests

headers = {"Accept": "application/json"}
response = requests.get("https://icanhazdadjoke.com/", headers=headers)


data = response.json()
print(data)
# Out:
# {'id': 'PZDAXL6pOCd', 'joke': 'What was a more important invention than the first telephone? The second one.', 'status': 200}

# %% [markdown]
# ### a) Create a Pydantic model with name Joke with the following fields
#
# id with type integer
# joke with type string

# %%
from pydantic import BaseModel

class Joke(BaseModel):
    id: int # vi vill tydligen ha en int
    joke: str

# %% [markdown]
# ### b) Validate the data from the API using the Joke model. Test out your Joke instance to see that you can access the joke and id fields.

# %%
# ID är ju ingen int så det lär inte fungera
try:
    joke_instance = Joke(**data)
    print("Joke ID:", joke_instance.id)
    print("Joke text:", joke_instance.joke)
except Exception as e:
    print("Validation error:", e)
# Out:
# Validation error: 1 validation error for Joke
# id
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='PZDAXL6pOCd', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/int_parsing

# %%
from pydantic import computed_field
import time

class Joke_correct(BaseModel):
    id: str
    joke: str
    
    # Computed fields - Fält som beräknas från andra fält i modellen.
    @computed_field
    @property
    def words_in_joke(self) -> int:
        """Return number of words in the joke"""
        return len(self.joke.split())

# %%
headers = {"Accept": "application/json"}
jokes_list = []

for i in range(10):
    response = requests.get("https://icanhazdadjoke.com/", headers=headers)
    data = response.json()
    joke = Joke_correct(**data)
    jokes_list.append(joke)

    print(f"{i+1}: {joke.joke} ({joke.words_in_joke} words)")

    time.sleep(2)  # 5 sek är ganska mycket, 2 räcker ofta
# Out:
# 1: Did you hear about the campsite that got visited by Bigfoot? It got in tents. (15 words)
# 2: Where do young cows eat lunch? In the calf-ateria. (9 words)
# 3: What do you call your friend who stands in a hole? Phil. (12 words)
# 4: So a duck walks into a pharmacy and says “Give me some chap-stick… and put it on my bill” (19 words)
# 5: I was at the library and asked if they have any books on "paranoia", the librarian replied, "yes, they are right behind you" (23 words)
# 6: Why did the scarecrow win an award? Because he was outstanding in his field. (14 words)
# 7: Why did the belt go to prison? He held up a pair of pants! (14 words)
# 8: Have you heard the story about the magic tractor? It drove down the road and turned into a field. (19 words)
# 9: Every morning when I go out, I get hit by bicycle. Every morning!  It's a vicious cycle. (17 words)
# 10: What do you call a group of killer whales playing instruments? An Orca-stra. (13 words)

# %%
print(jokes_list[0])
# Out:
# id='MCImjqrWvzd' joke='Did you hear about the campsite that got visited by Bigfoot? It got in tents.' words_in_joke=15

# %%
len(jokes_list)
# Out:
# 10

# %%
for i, j in enumerate(jokes_list):
    print(f"{i}: {j.joke} ({j.words_in_joke} words)")
# Out:
# 0: Did you hear about the campsite that got visited by Bigfoot? It got in tents. (15 words)
# 1: Where do young cows eat lunch? In the calf-ateria. (9 words)
# 2: What do you call your friend who stands in a hole? Phil. (12 words)
# 3: So a duck walks into a pharmacy and says “Give me some chap-stick… and put it on my bill” (19 words)
# 4: I was at the library and asked if they have any books on "paranoia", the librarian replied, "yes, they are right behind you" (23 words)
# 5: Why did the scarecrow win an award? Because he was outstanding in his field. (14 words)
# 6: Why did the belt go to prison? He held up a pair of pants! (14 words)
# 7: Have you heard the story about the magic tractor? It drove down the road and turned into a field. (19 words)
# 8: Every morning when I go out, I get hit by bicycle. Every morning!  It's a vicious cycle. (17 words)
# 9: What do you call a group of killer whales playing instruments? An Orca-stra. (13 words)

# %%
new_jokes_list = []

# %%
headers = {"Accept": "application/json"}
response = requests.get("https://icanhazdadjoke.com/", headers=headers)

data = response.json()
new_jokes_list.append(Joke_correct(**data))

# %%
# varje index, varje skämt
for i, j in enumerate(new_jokes_list):
    print(f"{i+1}: {j.joke} ({j.words_in_joke} words)")
# Out:
# 1: Why did Sweden start painting barcodes on the sides of their battleships? So they could Scandinavian. (16 words)

# %%
for i, j in enumerate(new_jokes_list):
    print(f"{i+1}: {j.joke} ({j.words_in_joke} words)")
# Out:
# 1: Why did Sweden start painting barcodes on the sides of their battleships? So they could Scandinavian. (16 words)
# 2: Why did the girl smear peanut butter on the road? To go with the traffic jam. (16 words)
