# %% [markdown]
# # # PYDANTIC

# %%
from pydantic import BaseModel

class User(BaseModel):
    id: int
    name: str
    
user = User(id=1, name="henke")
print(user)
# Out:
# id=1 name='henke'

# %%
user_2 = User(id="hallåeller", name="benke")
print(user_2)

# ValidationError: 1 validation error for User
# id
#  Input should be a valid integer, unable to parse string as an integer
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 user_2 = User(id="hallåeller", name="benke")
#       2 print(user_2)
#
# File c:\Users\henri\source\repos\Python\Objektorienterad programmering avancerad 1\ai_engineering_henrik_pilback\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %% [markdown]
# ### Create a BaseModel for a Person with the fields name, age, email, favourite pet. Add appropriate validation in each fields. Tips: you can use built-in EmailStr type in pydantic for validating email. Try out your Person class by instantiating it with different types of values for the fields to see proper validations.

# %%
from pydantic import EmailStr, Field

class Person(BaseModel):
    name: str = Field(min_length=2, max_length=50)
    age: int = Field(ge=0, le=120)
    email: EmailStr
    favourite_pet: str = Field(min_length=2)
    
# Kör uv pip install pydantic[email] för email-validator i konsolen

# %%
user = Person(name="henke", age=12, email="henriksnubben@gmail.com", favourite_pet="kattegatt")
print(user)
# Out:
# name='henke' age=12 email='henriksnubben@gmail.com' favourite_pet='kattegatt'

# %%
user2 = Person(name="henke", age="12", email="henriksnubben@gmail.com", favourite_pet="kattegatt")
print(user)
# Out:
# name='henke' age=12 email='henriksnubben@gmail.com' favourite_pet='kattegatt'

# %%
user3 = Person(name=1, age=12, email="henriksnubben@gmail.com", favourite_pet="kattegatt")
print(user3)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 user3 = Person(name=1, age=12, email="henriksnubben@gmail.com", favourite_pet="kattegatt")
#       2 print(user3)
#
# File c:\Users\henri\source\repos\Python\Objektorienterad programmering avancerad 1\ai_engineering_henrik_pilback\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
# ...

# %%
user4 = Person(name="henke", age=12, email=1234, favourite_pet="kattegatt")
print(user4)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 user4 = Person(name="henke", age=12, email=1234, favourite_pet="kattegatt")
#       2 print(user4)
#
# File c:\Users\henri\source\repos\Python\Objektorienterad programmering avancerad 1\ai_engineering_henrik_pilback\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
# ...

# %%
user5 = Person(name="henke", age=12, email="henriksnubben@gmail.com", favourite_pet=5)
print(user5)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 user5 = Person(name="henke", age=12, email="henriksnubben@gmail.com", favourite_pet=5)
#       2 print(user5)
#
# File c:\Users\henri\source\repos\Python\Objektorienterad programmering avancerad 1\ai_engineering_henrik_pilback\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
# ...

# %% [markdown]
# ### Use normal python class to replicate what you have created in b), i.e. create a Person class with proper input validation.

# %%
import re

class Person_python:
    def __init__(self, name: str, age: int, email: str, favourite_pet: str):
        # om namn inte är en string
        if not isinstance(name, str):
            raise TypeError("Name must be a string")
        if len(name) < 2 or len(name) > 50:
            raise ValueError("Name must be between 2 and 50 characters")
        self.name = name

        # ålder
        if not isinstance(age, int):
            raise TypeError("Age must be an integer")
        if age < 0 or age > 120:
            raise ValueError("Age must be between 0 and 120")
        self.age = age

        # email (enkel regex-check)
        if not isinstance(email, str):
            raise TypeError("Email must be a string")
        email_pattern = r"^[\w\.-]+@[\w\.-]+\.\w+$"
        if not re.match(email_pattern, email):
            raise ValueError("Invalid email format")
        self.email = email

        # favourite_pet
        if not isinstance(favourite_pet, str):
            raise TypeError("Favourite pet must be a string")
        if len(favourite_pet) < 2:
            raise ValueError("Favourite pet must have at least 2 characters")
        self.favourite_pet = favourite_pet

    def __repr__(self):
        return f"Person(name={self.name}, age={self.age}, email={self.email}, favourite_pet={self.favourite_pet})"

# %%
p1 = Person_python("Alice", 30, "alice@example.com", "Pikachu")
print(p1)

# Fel e-post
try:
    p2 = Person_python("Bob", 25, "inte_en_email", "Dog")
except Exception as e:
    print("Fel:", e)

# Fel ålder
try:
    p3 = Person_python("Charlie", -5, "charlie@example.com", "Cat")
except Exception as e:
    print("Fel:", e)
# Out:
# Person(name=Alice, age=30, email=alice@example.com, favourite_pet=Pikachu)
# Fel: Invalid email format
# Fel: Age must be between 0 and 120
